# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
teste = pd.read_csv('C:/Users/italo/.Data Science/Macro_Py/estudo.csv',encoding='latin-1')

# %%
teste
# Out:
#       Unnamed: 0     X    id  menina  branco  cidade_id  \
# 0              1     1     1       1       1         16
# 1              2     2     2       0       1          8
# 2              3     3     3       1       1          6
# 3              4     4     4       1       1          6
# 4              5     5     5       1       1          1
# ...          ...   ...   ...     ...     ...        ...
# 1132        1133  1133  1133       1       0         11
# 1133        1134  1134  1134       0       1          9
# 1134        1135  1135  1135       1       1          3
# 1135        1136  1136  1136       1       0         15
# 1136        1137  1137  1137       1       1          4
#
#                   escola_id  prof_id            name_muni          pib  \
# 0       Tamboril Do Piauí_4       62    Tamboril Do Piauí  4790.742326
# 1           Dom Inocêncio_1      120        Dom Inocêncio  4110.471929
# 2       Coronel José Dias_4      110    Coronel José Dias  3999.824452
# ...
